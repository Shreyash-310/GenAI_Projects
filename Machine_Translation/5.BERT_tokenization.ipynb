# %% [markdown]
# # BERT configuration<br>
# It is used to instantiate a BERT model based on the specified arguments.<br>
# It is a way to define the model architecture. <br>
# Instantiating a configuration with the defaults results in BERT bert-base-uncased architecture.

# %%
from transformers import BertModel, BertConfig

# Initializing a BERT bert-base-uncased style configuration
configuration = BertConfig()

# Initializing a model from the bert-base-uncased style configuration
model = BertModel(configuration)
# Accessing the model configuration
configuration = model.config

# %% [markdown]
# # BERT tokenizer

# %% [markdown]
# # Method1

# %% [markdown]
# BertForPreTraining : Bert Model with two heads on top as done during the pretraining: a masked language modeling head and a next sentence prediction (classification) head.<br>

# %%
from transformers import BertTokenizer, BertModel
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
inputs = tokenizer("Machine Translation using BERT", return_tensors="pt")
outputs = model(**inputs)

last_hidden_states = outputs.last_hidden_state

# %%
print(outputs)
# Out:
# BaseModelOutputWithPoolingAndCrossAttentions(last_hidden_state=tensor([[[-0.3961,  0.2678, -0.4073,  ..., -0.4346, -0.1967,  0.5913],
#          [-0.3519,  0.2906, -0.4836,  ..., -0.2454,  0.1633,  0.3069],
#          [ 0.0213,  0.4137, -0.0076,  ..., -1.0416, -0.0192,  0.8782],
#          [-0.5209,  0.3841, -0.7494,  ..., -0.4258, -0.3028,  0.5872],
#          [-0.4886, -0.7655, -0.7365,  ..., -0.1459, -0.0921,  0.0404],
#          [ 0.7961,  0.1699, -0.5127,  ..., -0.0086, -0.8875, -0.0972]]],
#        grad_fn=<NativeLayerNormBackward>), pooler_output=tensor([[-8.1459e-01, -2.0090e-01,  2.5791e-01,  5.6607e-01, -1.2343e-01,
#          -1.9850e-01,  7.0730e-01,  6.2455e-02,  5.2190e-01, -9.9978e-01,
#           2.2112e-01,  1.4463e-01,  9.8148e-01, -4.1085e-01,  8.6276e-01,
#          -4.3684e-01, -9.7610e-02, -4.7251e-01,  1.7872e-01, -4.8157e-01,
#           4.9854e-01,  9.8535e-01,  5.7296e-01,  2.1969e-01,  2.0886e-01,
# ...

# %% [markdown]
# # Method2

# %%
text = "BERT is the state-of the art technologywhich uses Transformers"
marker = "[CLS] " + text + " [SEP]"

# Tokenize our sentence with the BERT tokenizer.
tokens = tokenizer.tokenize(marker)

# Map the token strings to their vocabulary indeces.
index = tokenizer.convert_tokens_to_ids(tokens)

# Print  the tokens.
print('-------------------')
print('Tokens generated from BERT')
print('-------------------')
print (tokens)
# Display the words with their indeces.
print('------------------------')
print('TOKEN           INDEX')
print('------------------------')
for tup in zip(tokens, index):
    print('{:<12} {:>6,}'.format(tup[0], tup[1]))
# Out:
# -------------------
# Tokens generated from BERT
# -------------------
# ['[CLS]', 'bert', 'is', 'the', 'state', '-', 'of', 'the', 'art', 'technology', '##w', '##hic', '##h', 'uses', 'transformers', '[SEP]']
# ------------------------
# TOKEN           INDEX
# ------------------------
# [CLS]           101
# bert         14,324
# is            2,003
# the           1,996
# state         2,110
# -             1,011
# of            1,997
# the           1,996
# art           2,396
# technology    2,974
# ##w           2,860
# ##hic        16,066
# ##h           2,232
# uses          3,594
# transformers 19,081
# [SEP]           102
